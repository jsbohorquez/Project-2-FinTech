# %%
import yfinance as yf

# %%
sp500 = yf.Ticker('^GSPC')

# %%
#get stock info
sp500.info
# Out:
# {'exchange': 'SNP',
#  'shortName': 'S&P 500',
#  'exchangeTimezoneName': 'America/New_York',
#  'exchangeTimezoneShortName': 'EDT',
#  'isEsgPopulated': False,
#  'gmtOffSetMilliseconds': '-14400000',
#  'quoteType': 'INDEX',
#  'symbol': '^GSPC',
#  'messageBoardId': 'finmb_INDEXGSPC',
#  'market': 'us_market',
#  'previousClose': 3759.89,
#  'regularMarketOpen': 3774.71,
#  'twoHundredDayAverage': 4409.2383,
#  'trailingAnnualDividendYield': None,
#  'payoutRatio': None,
#  'volume24Hr': None,
#  'regularMarketDayHigh': 3802.58,
#  'navPrice': None,
#  'averageDailyVolume10Day': 4431256000,
#  'totalAssets': None,
#  'regularMarketPreviousClose': 3759.89,
#  'fiftyDayAverage': 4075.559,
#  'trailingAnnualDividendRate': None,
#  'open': 3774.71,
#  'toCurrency': None,
#  'averageVolume10days': 4431256000,
#  'expireDate': None,
#  'yield': None,
#  'algorithm': None,
#  'dividendRate': None,
#  'exDividendDate': None,
#  'beta': None,
#  'circulatingSupply': None,
# ...

# %%
# get historical market data
sp500_df = sp500.history(period='1mo', start='2022-06-02', end='2022-06-22')
sp500_df
# Out:
#                    Open         High          Low        Close      Volume  \
# Date
# 2022-06-02  4095.409912  4177.509766  4074.370117  4176.819824  3604930000
# 2022-06-03  4137.569824  4142.669922  4098.669922  4108.540039  3107080000
# 2022-06-06  4134.720215  4168.779785  4109.180176  4121.430176  3852050000
# 2022-06-07  4096.470215  4164.859863  4080.189941  4160.680176  3476470000
# 2022-06-08  4147.120117  4160.140137  4107.200195  4115.770020  3090180000
# 2022-06-09  4101.649902  4119.100098  4017.169922  4017.820068  3192330000
# 2022-06-10  3974.389893  3974.389893  3900.159912  3900.860107  3936120000
# 2022-06-13  3838.149902  3838.149902  3734.300049  3749.629883  4572820000
# 2022-06-14  3763.520020  3778.179932  3705.679932  3735.479980  4126400000
# 2022-06-15  3764.050049  3837.560059  3722.300049  3789.989990  4474610000
# 2022-06-16  3728.179932  3728.179932  3639.770020  3666.770020  4511200000
# ...
